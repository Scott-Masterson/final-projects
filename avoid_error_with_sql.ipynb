# %% [markdown]
# ### GOAL: Combine columns in dataset cleanly using sql to avoid indexing errors
# #### Scott Masterson, Applied Math and Statistics
# ###### Emory University

# %%
import pandas as pd
import numpy as np

#sql
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())

# %%
#read data set from excel file on my computer
df = pd.read_excel('/Users/scottmasterson/Documents/Resume_Job/All_Course_Offerings.xlsx', 
                   usecols = 'A:T', skiprows = 5)

df.columns = df.iloc[0]
df = df.reindex(df.index.drop(0)).reset_index(drop=True)
df.columns.name = None


#Check columns to view unexpected inputs
list(df.columns.values)
# Out:
# ['Term',
#  'Subject',
#  'Catalogs',
#  'Sections',
#  'Programs',
#  nan,
#  'Title',
#  'Max Units',
#  'Instructor',
#  'Bldg & Rm',
#  nan,
#  'M',
#  'TU',
#  'W',
#  'TH',
#  'F',
#  'Start ',
#  'End',
#  'Capacity',
#  'Enr']

# %%
#rename and check to avoid errors
df = df.rename(columns={"Start ": "Start"})
df.head()
# Out:
#    Term Subject Catalogs Sections Programs  NaN  \
# 0  5229     ACT      710     5102      PHD  NaN
# 1  5229     ACT      200     1101      BBA  NaN
# 2  5229     ACT      200     1102      BBA  NaN
# 3  5229     ACT      200     1103      BBA  NaN
# 4  5229     ACT      200     1104      BBA  NaN
#
#                             Title Max Units      Instructor Bldg & Rm  NaN  \
# 0           Accounting Research I         3  Dichev,Ilia D.  GFC_W520  NaN
# 1  Accounting:The Language of Bus         3  Rackliffe,Usha   GBS_130  NaN
# 2  Accounting:The Language of Bus         3  Rackliffe,Usha   GBS_130  NaN
# 3  Accounting:The Language of Bus         3    Zhao,Jianxin   GBS_304  NaN
# 4  Accounting:The Language of Bus         3    Zhao,Jianxin   GBS_130  NaN
#
#      M   TU    W   TH    F  Start    End Capacity Enr
# 0    M  NaN  NaN  NaN  NaN  09:00  12:00       66   3
# 1    M  NaN    W  NaN  NaN  13:00  14:15       62   6
# 2    M  NaN    W  NaN  NaN  14:30  15:45       62   9
# 3  NaN   TU  NaN   TH  NaN  10:00  11:15       62  58
# 4  NaN   TU  NaN   TH  NaN  13:00  14:15       62  62

# %%
#select inportant columns
df_trim = df[['Subject', 'Instructor', 'M', 'TU', 'W', 'TH', 'F', 'Start', 'End']]

#create new columns
df_trim['Time'] = df_trim['Start'] + ' ' + '-' + ' ' + df_trim['End']
df_trim.head()
# Out:
# <ipython-input-162-a51d2287d9d1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trim['Time'] = df_trim['Start'] + ' ' + '-' + ' ' + df_trim['End']
#   Subject      Instructor    M   TU    W   TH    F  Start    End  \
# 0     ACT  Dichev,Ilia D.    M  NaN  NaN  NaN  NaN  09:00  12:00
# 1     ACT  Rackliffe,Usha    M  NaN    W  NaN  NaN  13:00  14:15
# 2     ACT  Rackliffe,Usha    M  NaN    W  NaN  NaN  14:30  15:45
# 3     ACT    Zhao,Jianxin  NaN   TU  NaN   TH  NaN  10:00  11:15
# 4     ACT    Zhao,Jianxin  NaN   TU  NaN   TH  NaN  13:00  14:15
#
#             Time
# 0  09:00 - 12:00
# 1  13:00 - 14:15
# 2  14:30 - 15:45
# 3  10:00 - 11:15
# 4  13:00 - 14:15

# %%
#encountered an indexing error here that didn't allow the selection of 'Time'
df_error = df[['Time']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-60ef14516837> in <module>
#       1 #encountered an indexing error here that didn't allow the selection of 'Time'
# ----> 2 df_error = df[['Time']]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['Time'], dtype='object')] are in the [columns]"

# %%
#use sql to bypass error
clean_data = mysql('''SELECT Subject, Instructor, M, TU, W, TH, F, Time
                      FROM df_trim''')

print(type(clean_data))

#check to see if sql resolved issue
clean_data[['Time']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               Time
# 0    09:00 - 12:00
# 1    13:00 - 14:15
# 2    14:30 - 15:45
# 3    10:00 - 11:15
# 4    13:00 - 14:15
# ..             ...
# 267           None
# 268           None
# 269           None
# 270           None
# 271           None
#
# [272 rows x 1 columns]

# %%
#final dataset
clean_data
# Out:
#     Subject          Instructor     M    TU     W    TH     F           Time
# 0       ACT      Dichev,Ilia D.     M  None  None  None  None  09:00 - 12:00
# 1       ACT      Rackliffe,Usha     M  None     W  None  None  13:00 - 14:15
# 2       ACT      Rackliffe,Usha     M  None     W  None  None  14:30 - 15:45
# 3       ACT        Zhao,Jianxin  None    TU  None    TH  None  10:00 - 11:15
# 4       ACT        Zhao,Jianxin  None    TU  None    TH  None  13:00 - 14:15
# ..      ...                 ...   ...   ...   ...   ...   ...            ...
# 267     BUS  Lord,Michael David  None  None  None  None  None           None
# 268     BUS  Lord,Michael David  None  None  None  None  None           None
# 269     BUS  Lord,Michael David  None  None  None  None  None           None
# 270     BUS  Lord,Michael David  None  None  None  None  None           None
# 271     BUS  Lord,Michael David  None  None  None  None  None           None
#
# [272 rows x 8 columns]
